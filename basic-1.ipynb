# %%
import turicreate as tc

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import HoverTool
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
trial = tc.SFrame.read_csv('2018_testing.csv')
trial
# Out:
# Finished parsing file /home/siddhi/2018_testing.csv
# Parsing completed. Parsed 32 lines in 0.02342 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,int,float,str,str,int,float,float,float,float,float,str,int,int,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/siddhi/2018_testing.csv
# Parsing completed. Parsed 32 lines in 0.015645 secs.
# Columns:
# 	State/UT	str
# 	Dengue cases	int
# 	temperature-air	float
# 	population	str
# 	population to cases ratio	str
# 	rainfall	int
# 	temperature-water	float
# 	Dissolved O2	float
# 	pH	float
# 	Nitrate	float
# 	Faecal Coliform	float
# 	traits_written	str
# 	traits	int
# 	1	int
# 	high population density and lack of accessibility of tap water and malnutrition	str
#
# Rows: 32
#
# Data:
# +-------------------+--------------+-----------------+--------------+---------------------------+
# |      State/UT     | Dengue cases | temperature-air |  population  | population to cases ratio |
# +-------------------+--------------+-----------------+--------------+---------------------------+
# |   Andhra Pradesh  |     4011     |      27.95      | 5,39,03,000  |           13,439          |
# | Arunachal Pradesh |      1       |      18.54      |  13,83,000   |         13,83,000         |
# |       Assam       |     166      |      23.02      | 3,12,05,000  |          1,87,982         |
# |       Bihar       |     2142     |      24.96      | 11,98,13,000 |           55,935          |
# |     Chandigarh    |     301      |      24.15      |  11,62,055   |           3,861           |
# |    Chattisgarh    |     2674     |      25.95      | 2,83,97,000  |           10,620          |
# |       Delhi       |     7136     |      25.77      | 1,98,62,000  |           2,783           |
# |        Goa        |     335      |      27.26      |  15,85,000   |           4,731           |
# |      Gujarat      |     7579     |       27.6      | 6,38,72,000  |           8,427           |
# |      Haryana      |     1898     |      25.57      | 2,82,00,000  |           14,858          |
# +-------------------+--------------+-----------------+--------------+---------------------------+
# +----------+-------------------+--------------+------+---------+-----------------+
# | rainfall | temperature-water | Dissolved O2 |  pH  | Nitrate | Faecal Coliform |
# +----------+-------------------+--------------+------+---------+-----------------+
# |   912    |        25.7       |     6.7      | 7.8  |   1.69  |       16.0      |
# |   2782   |        25.4       |     6.0      | 7.5  |   0.0   |       0.0       |
# |   2818   |        24.2       |     6.3      | 7.2  |   1.0   |      4371.0     |
# |   1256   |        23.8       |     8.1      | 7.5  |   0.6   |      8081.0     |
# |   617    |        25.0       |     8.9      | 7.8  |   1.0   |     13502.5     |
# |   1255   |        27.5       |     7.0      | 7.75 |   2.3   |      227.0      |
# |   617    |        25.7       |     4.4      | 7.6  |   0.3   |    9858377.5    |
# |   3005   |        30.0       |     6.7      | 6.6  |   0.7   |      110.0      |
# |   843    |        27.7       |     7.7      | 8.0  |   0.7   |      110.0      |
# |   617    |        23.0       |     7.4      | 7.2  |   2.9   |       18.0      |
# +----------+-------------------+--------------+------+---------+-----------------+
# +-------------------------------+--------+------+-------------------------------+
# |         traits_written        | traits |  1   | high population density an... |
# +-------------------------------+--------+------+-------------------------------+
# | sea coast and temperature ... |   45   |  2   | high vegetation and altitu... |
# |  high vegetation and altitude |   2    |  3   | high nitrate value and dis... |
# | urbanisation, high vegetat... |   29   |  4   |    temperature range 18-34    |
# | malnutrition, improper san... |   1    |  5   |  sea coast and humidity rate  |
# | high contamination level o... |   79   |  6   |       high tourism rate       |
# | high transmission in tempe... |   4    |  7   | high contamination level o... |
# | high contamination level o... |  179   |  8   | climate change and annual ... |
# | low population, temperatur... |  456   |  9   |          urbanization         |
# | temperature range 26-29, h... |  459   | None |                               |
# | high nitrate value, temper... |  349   | None |                               |
# +-------------------------------+--------+------+-------------------------------+
# [32 rows x 15 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
trial.groupby('traits',operations={'count':tc.aggregate.COUNT()}).sort('count', ascending= False).head(5)
# Out:
# Columns:
# 	traits	int
# 	count	int
#
# Rows: 5
#
# Data:
# +--------+-------+
# | traits | count |
# +--------+-------+
# |   2    |   3   |
# |  459   |   2   |
# |   4    |   2   |
# |   1    |   2   |
# |   68   |   2   |
# +--------+-------+
# [5 rows x 2 columns]

# %%
giraffe_reviews = trial[trial['State/UT']== 'Arunachal Pradesh']
giraffe_reviews['traits'].show()
# Out:
# Materializing SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"description\": \"A simple bar chart with embedded data.\", \"autosize\": {\"type\": \"fit\", \"resize\": false, \"contains\": \"padding\"}, \"width\": 720, \"height\": 550, \"padding\": 8, \"title\": \"Distribution of Values [integer]\", \"style\": \"cell\", \"signals\": [{\"name\": \"bins\", \"update\": \"data(\\\"bins_data\\\")[0]\"}, {\"name\": \"binCount\", \"update\": \"(bins.stop - bins.start) / bins.step\"}, {\"name\": \"nullGap\", \"update\": \"data(\\\"nulls\\\").length ? 10 : 0\"}, {\"name\": \"barStep\", \"update\": \"(width - nullGap) / (1 + binCount)\"}], \"data\": [{\"name\": \"source_2\", \"values\": [{\"left\": -7, \"right\": -6, \"count\": 0}, {\"left\": -6, \"right\": -5, \"count\": 0}, {\"left\": -5, \"right\": -4, \"count\": 0}, {\"left\": -4, \"right\": -3, \"count\": 0}, {\"left\": -3, \"right\": -2, \"count\": 0}, {\"left\": -2, \"right\": -1, \"count\": 0}, {\"left\": -1, \"right\": 0, \"count\": 0}, {\"left\": 0, \"right\": 1, \"count\": 0}, {\"left\": 1, \"right\": 2, \"count\": 0}, {\"left\": 2, \"right\": 3, \"count\": 1}, {\"left\": 3, \"right\": 4, \"count\": 0}, {\"left\": 4, \"right\": 5, \"count\": 0}, {\"left\": 5, \"right\": 6, \"count\": 0}, {\"left\": 6, \"right\": 7, \"count\": 0}, {\"left\": 7, \"right\": 8, \"count\": 0}, {\"left\": 8, \"right\": 9, \"count\": 0}, {\"left\": 9, \"right\": 10, \"count\": 0}, {\"left\": 10, \"right\": 11, \"count\": 0}, {\"left\": 11, \"right\": 12, \"count\": 0}, {\"left\": 12, \"right\": 13, \"count\": 0}, {\"start\": -7, \"stop\": 13, \"step\": 1}]}, {\"name\": \"counts\", \"source\": \"source_2\", \"transform\": [{\"type\": \"filter\", \"expr\": \"datum[\\\"missing\\\"] !== true &amp;&amp; datum[\\\"count\\\"] != null\"}]}, {\"name\": \"nulls\", \"source\": \"source_2\", \"transform\": [{\"expr\": \"datum[\\\"missing\\\"] === true &amp;&amp; datum[\\\"count\\\"] != null\", \"type\": \"filter\"}]}, {\"name\": \"bins_data\", \"source\": \"source_2\", \"transform\": [{\"expr\": \"datum[\\\"start\\\"] != null &amp;&amp; datum[\\\"stop\\\"] != null &amp;&amp; datum[\\\"s ...

# %%
trial['word_count'] = tc.text_analytics.count_words(trial['traits_written'])
trial.head(5)
# Out:
# Columns:
# 	State/UT	str
# 	Dengue cases	int
# 	temperature-air	float
# 	population	str
# 	population to cases ratio	str
# 	rainfall	int
# 	temperature-water	float
# 	Dissolved O2	float
# 	pH	float
# 	Nitrate	float
# 	Faecal Coliform	float
# 	traits_written	str
# 	traits	int
# 	1	int
# 	high population density and lack of accessibility of tap water and malnutrition	str
# 	word_count	dict
#
# Rows: 5
#
# Data:
# +-------------------+--------------+-----------------+--------------+---------------------------+
# |      State/UT     | Dengue cases | temperature-air |  population  | population to cases ratio |
# +-------------------+--------------+-----------------+--------------+---------------------------+
# |   Andhra Pradesh  |     4011     |      27.95      | 5,39,03,000  |           13,439          |
# | Arunachal Pradesh |      1       |      18.54      |  13,83,000   |         13,83,000         |
# |       Assam       |     166      |      23.02      | 3,12,05,000  |          1,87,982         |
# |       Bihar       |     2142     |      24.96      | 11,98,13,000 |           55,935          |
# |     Chandigarh    |     301      |      24.15      |  11,62,055   |           3,861           |
# +-------------------+--------------+-----------------+--------------+---------------------------+
# +----------+-------------------+--------------+-----+---------+-----------------+
# | rainfall | temperature-water | Dissolved O2 |  pH | Nitrate | Faecal Coliform |
# +----------+-------------------+--------------+-----+---------+-----------------+
# |   912    |        25.7       |     6.7      | 7.8 |   1.69  |       16.0      |
# |   2782   |        25.4       |     6.0      | 7.5 |   0.0   |       0.0       |
# |   2818   |        24.2       |     6.3      | 7.2 |   1.0   |      4371.0     |
# |   1256   |        23.8       |     8.1      | 7.5 |   0.6   |      8081.0     |
# |   617    |        25.0       |     8.9      | 7.8 |   1.0   |     13502.5     |
# +----------+-------------------+--------------+-----+---------+-----------------+
# +-------------------------------+--------+---+-------------------------------+
# |         traits_written        | traits | 1 | high population density an... |
# +-------------------------------+--------+---+-------------------------------+
# | sea coast and temperature ... |   45   | 2 | high vegetation and altitu... |
# |  high vegetation and altitude |   2    | 3 | high nitrate value and dis... |
# | urbanisation, high vegetat... |   29   | 4 |    temperature range 18-34    |
# | malnutrition, improper san... |   1    | 5 |  sea coast and humidity rate  |
# | high contamination level o... |   79   | 6 |       high tourism rate       |
# +-------------------------------+--------+---+-------------------------------+
# +-------------------------------+
# |           word_count          |
# +-------------------------------+
# | {'18': 1.0, 'range': 1.0, ... |
# | {'altitude': 1.0, 'and': 1... |
# | {'and': 1.0, 'vegetation':... |
# | {'accessbility': 1.0, 'imp... |
# | {'urbanization': 1.0, 'wat... |
# +-------------------------------+
# [5 rows x 16 columns]

# %%
selected_words = ['sea', 'coast', 'high', 'vegetation', 'altitude', 'climate', 'change',
                  'annual', 'rise', 'tourism','humidity', 'rate','urbanization','population', 
                  'lack', 'water', 'tap', 'malnutrition', 'temperature', 
                  'contamination', 'nitrate', 'accessibility', 'rainfall']
# 'climate', 'change', 'annual', 'rise', 'tourism', 'humidity', 'rate', 
# Loop through word counts to create a classifier for only a few words 
# Created an individual column for each item 
for word in selected_words:
    trial[word] = trial['word_count'].apply(lambda counts: counts.get(word, 0))

trial.head(5)
# Out:
# Columns:
# 	State/UT	str
# 	Dengue cases	int
# 	temperature-air	float
# 	population	float
# 	population to cases ratio	str
# 	rainfall	float
# 	temperature-water	float
# 	Dissolved O2	float
# 	pH	float
# 	Nitrate	float
# 	Faecal Coliform	float
# 	traits_written	str
# 	traits	int
# 	1	int
# 	high population density and lack of accessibility of tap water and malnutrition	str
# 	word_count	dict
# 	sea	float
# 	coast	float
# 	high	float
# 	vegetation	float
# 	altitude	float
# 	urbanization	float
# 	lack	float
# 	water	float
# 	tap	float
# 	malnutrition	float
# 	temperature	float
# 	contamination	float
# 	nitrate	float
# 	accessibility	int
# 	critical	int
# 	climate	float
# 	change	float
# 	annual	float
# 	rise	float
# 	tourism	float
# 	humidity	int
# 	rate	float
#
# Rows: 5
#
# Data:
# +-------------------+--------------+-----------------+------------+---------------------------+
# |      State/UT     | Dengue cases | temperature-air | population | population to cases ratio |
# +-------------------+--------------+-----------------+------------+---------------------------+
# |   Andhra Pradesh  |     4011     |      27.95      |    0.0     |           13,439          |
# | Arunachal Pradesh |      1       |      18.54      |    0.0     |         13,83,000         |
# |       Assam       |     166      |      23.02      |    0.0     |          1,87,982         |
# |       Bihar       |     2142     |      24.96      |    1.0     |           55,935          |
# |     Chandigarh    |     301      |      24.15      |    0.0     |           3,861           |
# +-------------------+--------------+-----------------+------------+---------------------------+
# +----------+-------------------+--------------+-----+---------+-----------------+
# | rainfall | temperature-water | Dissolved O2 |  pH | Nitrate | Faecal Coliform |
# +----------+-------------------+--------------+-----+---------+-----------------+
# |   0.0    |        25.7       |     6.7      | 7.8 |   1.69  |       16.0      |
# |   0.0    |        25.4       |     6.0      | 7.5 |   0.0   |       0.0       |
# |   0.0    |        24.2       |     6.3      | 7.2 |   1.0   |      4371.0     |
# |   0.0    |        23.8       |     8.1      | 7.5 |   0.6   |      8081.0     |
# |   0.0    |        25.0       |     8.9      | 7.8 |   1.0   |     13502.5     |
# +----------+-------------------+--------------+-----+---------+-----------------+
# +-------------------------------+--------+---+-------------------------------+
# |         traits_written        | traits | 1 | high population density an... |
# +-------------------------------+--------+---+-------------------------------+
# | sea coast and temperature ... |   45   | 2 | high vegetation and altitu... |
# |  high vegetation and altitude |   2    | 3 | high nitrate value and dis... |
# | urbanisation, high vegetat... |   29   | 4 |    temperature range 18-34    |
# | malnutrition, improper san... |   1    | 5 |  sea coast and humidity rate  |
# | high contamination level o... |   79   | 6 |       high tourism rate       |
# +-------------------------------+--------+---+-------------------------------+
# +-------------------------------+-----+-------+------+------------+-----+
# |           word_count          | sea | coast | high | vegetation | ... |
# +-------------------------------+-----+-------+------+------------+-----+
# | {'18': 1.0, 'range': 1.0, ... | 1.0 |  1.0  | 0.0  |    0.0     | ... |
# | {'altitude': 1.0, 'and': 1... | 0.0 |  0.0  | 1.0  |    1.0     | ... |
# | {'and': 1.0, 'vegetation':... | 0.0 |  0.0  | 1.0  |    1.0     | ... |
# | {'accessbility': 1.0, 'imp... | 0.0 |  0.0  | 1.0  |    0.0     | ... |
# | {'urbanization': 1.0, 'wat... | 0.0 |  0.0  | 1.0  |    0.0     | ... |
# +-------------------------------+-----+-------+------+------------+-----+
# [5 rows x 38 columns]

# %%
trial['traits'].show
# Out:
# <bound method SArray.show of dtype: int
# Rows: 31
# [45, 2, 29, 1, 79, 4, 179, 456, 459, 349, 68, 68, 17, 579, 459, 376, 1349, 24, 2, 7, 234, 467, 347, 13, 2, 249, 49, 24, 1, 67, 15]>

# %%
trial = trial[trial['Dengue cases']!= 0]

#positive sentiment = 4-star or 5-star reviews
trial['critical'] = trial['Dengue cases'] >= 2000

trial.head(5)
# Out:
# Columns:
# 	State/UT	str
# 	Dengue cases	int
# 	temperature-air	float
# 	population	float
# 	population to cases ratio	str
# 	rainfall	float
# 	temperature-water	float
# 	Dissolved O2	float
# 	pH	float
# 	Nitrate	float
# 	Faecal Coliform	float
# 	traits_written	str
# 	traits	int
# 	1	int
# 	high population density and lack of accessibility of tap water and malnutrition	str
# 	word_count	dict
# 	sea	float
# 	coast	float
# 	high	float
# 	vegetation	float
# 	altitude	float
# 	urbanization	float
# 	lack	float
# 	water	float
# 	tap	float
# 	malnutrition	float
# 	temperature	float
# 	contamination	float
# 	nitrate	float
# 	accessibility	int
# 	critical	int
# 	climate	float
# 	change	float
# 	annual	float
# 	rise	float
# 	tourism	float
# 	humidity	int
# 	rate	float
#
# Rows: 5
#
# Data:
# +-------------------+--------------+-----------------+------------+---------------------------+
# |      State/UT     | Dengue cases | temperature-air | population | population to cases ratio |
# +-------------------+--------------+-----------------+------------+---------------------------+
# |   Andhra Pradesh  |     4011     |      27.95      |    0.0     |           13,439          |
# | Arunachal Pradesh |      1       |      18.54      |    0.0     |         13,83,000         |
# |       Assam       |     166      |      23.02      |    0.0     |          1,87,982         |
# |       Bihar       |     2142     |      24.96      |    1.0     |           55,935          |
# |     Chandigarh    |     301      |      24.15      |    0.0     |           3,861           |
# +-------------------+--------------+-----------------+------------+---------------------------+
# +----------+-------------------+--------------+-----+---------+-----------------+
# | rainfall | temperature-water | Dissolved O2 |  pH | Nitrate | Faecal Coliform |
# +----------+-------------------+--------------+-----+---------+-----------------+
# |   0.0    |        25.7       |     6.7      | 7.8 |   1.69  |       16.0      |
# |   0.0    |        25.4       |     6.0      | 7.5 |   0.0   |       0.0       |
# |   0.0    |        24.2       |     6.3      | 7.2 |   1.0   |      4371.0     |
# |   0.0    |        23.8       |     8.1      | 7.5 |   0.6   |      8081.0     |
# |   0.0    |        25.0       |     8.9      | 7.8 |   1.0   |     13502.5     |
# +----------+-------------------+--------------+-----+---------+-----------------+
# +-------------------------------+--------+---+-------------------------------+
# |         traits_written        | traits | 1 | high population density an... |
# +-------------------------------+--------+---+-------------------------------+
# | sea coast and temperature ... |   45   | 2 | high vegetation and altitu... |
# |  high vegetation and altitude |   2    | 3 | high nitrate value and dis... |
# | urbanisation, high vegetat... |   29   | 4 |    temperature range 18-34    |
# | malnutrition, improper san... |   1    | 5 |  sea coast and humidity rate  |
# | high contamination level o... |   79   | 6 |       high tourism rate       |
# +-------------------------------+--------+---+-------------------------------+
# +-------------------------------+-----+-------+------+------------+-----+
# |           word_count          | sea | coast | high | vegetation | ... |
# +-------------------------------+-----+-------+------+------------+-----+
# | {'18': 1.0, 'range': 1.0, ... | 1.0 |  1.0  | 0.0  |    0.0     | ... |
# | {'altitude': 1.0, 'and': 1... | 0.0 |  0.0  | 1.0  |    1.0     | ... |
# | {'and': 1.0, 'vegetation':... | 0.0 |  0.0  | 1.0  |    1.0     | ... |
# | {'accessbility': 1.0, 'imp... | 0.0 |  0.0  | 1.0  |    0.0     | ... |
# | {'urbanization': 1.0, 'wat... | 0.0 |  0.0  | 1.0  |    0.0     | ... |
# +-------------------------------+-----+-------+------+------------+-----+
# [5 rows x 38 columns]

# %%
trial['Dengue cases'].show()
# Out:
# Materializing SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"description\": \"A simple bar chart with embedded data.\", \"autosize\": {\"type\": \"fit\", \"resize\": false, \"contains\": \"padding\"}, \"width\": 720, \"height\": 550, \"padding\": 8, \"title\": \"Distribution of Values [integer]\", \"style\": \"cell\", \"signals\": [{\"name\": \"bins\", \"update\": \"data(\\\"bins_data\\\")[0]\"}, {\"name\": \"binCount\", \"update\": \"(bins.stop - bins.start) / bins.step\"}, {\"name\": \"nullGap\", \"update\": \"data(\\\"nulls\\\").length ? 10 : 0\"}, {\"name\": \"barStep\", \"update\": \"(width - nullGap) / (1 + binCount)\"}], \"data\": [{\"name\": \"source_2\", \"values\": [{\"left\": -354, \"right\": 526, \"count\": 12}, {\"left\": 526, \"right\": 1406, \"count\": 1}, {\"left\": 1406, \"right\": 2286, \"count\": 2}, {\"left\": 2286, \"right\": 3166, \"count\": 1}, {\"left\": 3166, \"right\": 4046, \"count\": 2}, {\"left\": 4046, \"right\": 4926, \"count\": 6}, {\"left\": 4926, \"right\": 5806, \"count\": 1}, {\"left\": 5806, \"right\": 6686, \"count\": 0}, {\"left\": 6686, \"right\": 7566, \"count\": 1}, {\"left\": 7566, \"right\": 8446, \"count\": 1}, {\"left\": 8446, \"right\": 9326, \"count\": 0}, {\"left\": 9326, \"right\": 10206, \"count\": 1}, {\"left\": 10206, \"right\": 11086, \"count\": 1}, {\"left\": 11086, \"right\": 11966, \"count\": 0}, {\"left\": 11966, \"right\": 12846, \"count\": 0}, {\"left\": 12846, \"right\": 13726, \"count\": 0}, {\"left\": 13726, \"right\": 14606, \"count\": 0}, {\"left\": 14606, \"right\": 15486, \"count\": 1}, {\"left\": 15486, \"right\": 16366, \"count\": 0}, {\"left\": 16366, \"right\": 17246, \"count\": 1}, {\"start\": -354, \"stop\": 17246, \"step\": 880}]}, {\"name\": \"counts\", \"source\": \"source_2\", \"transform\": [{\"type\": \"filter\", \"expr\": \"datum[\\\"missing\\\"] !== true &amp;&amp; datum[\\\"count\\\"] != null\"}]}, {\"name\": \"nulls\", \"source\": \"source_2\", \"transform\": [{\"expr\": \"datum[\\\"missing\\\"] === true &amp;&amp; datum[\\\"count\\\"] != null\", \"type\": \"filter\"}]}, {\"name\": \"bins_data\", \"source\": \"source_2 ...

# %%
train_data,test_data = trial.random_split(.7,seed=0)

# %%
training_model = tc.logistic_classifier.create(train_data,
                                                        target='critical', features=['Dengue cases'], 
                                                        validation_set=test_data)
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 22
# Number of classes           : 2
# Number of feature columns   : 1
# Number of unpacked features : 1
# Number of coefficients      : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Elapsed Time | Training Accuracy | Validation Accuracy |
# +-----------+----------+--------------+-------------------+---------------------+
# | 1         | 2        | 0.000690     | 0.909091          | 1.000000            |
# | 2         | 3        | 0.001746     | 0.909091          | 1.000000            |
# | 3         | 4        | 0.002687     | 0.954545          | 1.000000            |
# | 4         | 5        | 0.003567     | 0.954545          | 1.000000            |
# | 5         | 6        | 0.004557     | 1.000000          | 1.000000            |
# | 6         | 7        | 0.005476     | 1.000000          | 1.000000            |
# +-----------+----------+--------------+-------------------+---------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
predictions = training_model.classify(test_data)
print (predictions)
# Out:
# +-------+--------------------+
# | class |    probability     |
# +-------+--------------------+
# |   0   | 0.9658715999503549 |
# |   0   | 0.9437663761933075 |
# |   1   | 0.9720396343844744 |
# |   1   | 0.9865180289514386 |
# |   1   | 0.9860419238046535 |
# |   1   | 0.9883891370719419 |
# |   1   | 0.9569638390028182 |
# |   0   | 0.9185452007662028 |
# |   1   | 0.9999999999949982 |
# +-------+--------------------+
# [9 rows x 2 columns]

# %%
roc = training_model.evaluate(test_data, metric= 'roc_curve')
roc
# Out:
# {'roc_curve': Columns:
#  	threshold	float
#  	fpr	float
#  	tpr	float
#  	p	int
#  	n	int
#
#  Rows: 1001
#
#  Data:
#  +-----------+-----+-----+---+---+
#  | threshold | fpr | tpr | p | n |
#  +-----------+-----+-----+---+---+
#  |    0.0    | 1.0 | 1.0 | 6 | 3 |
#  |   0.001   | 1.0 | 1.0 | 6 | 3 |
#  |   0.002   | 1.0 | 1.0 | 6 | 3 |
#  |   0.003   | 1.0 | 1.0 | 6 | 3 |
#  |   0.004   | 1.0 | 1.0 | 6 | 3 |
#  |   0.005   | 1.0 | 1.0 | 6 | 3 |
#  |   0.006   | 1.0 | 1.0 | 6 | 3 |
#  |   0.007   | 1.0 | 1.0 | 6 | 3 |
#  |   0.008   | 1.0 | 1.0 | 6 | 3 |
#  |   0.009   | 1.0 | 1.0 | 6 | 3 |
#  +-----------+-----+-----+---+---+
#  [1001 rows x 5 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.}

# %%
result = training_model.evaluate(test_data)
print ("Accuracy             : {}".format(result['accuracy']))
print ("Area under ROC Curve : {}".format(result['auc']))
print ("Confusion Matrix     : \n{}".format(result['confusion_matrix']))
print ("F1_score             : {}".format(result['f1_score']))
print ("Precision            : {}".format(result['precision']))
print ("Recall               : {}".format(result['recall']))
print ("Log_loss             : {}".format(result['log_loss']))
# Out:
# Accuracy             : 1.0
# Area under ROC Curve : 1.0
# Confusion Matrix     :
# +--------------+-----------------+-------+
# | target_label | predicted_label | count |
# +--------------+-----------------+-------+
# |      0       |        0        |   3   |
# |      1       |        1        |   6   |
# +--------------+-----------------+-------+
# [2 rows x 3 columns]
#
# F1_score             : 1.0
# Precision            : 1.0
# Recall               : 1.0
# Log_loss             : 0.032135824010827506

# %%
trialdata = trial.copy()
trialdata['predicted_traits'] = training_model.predict(trialdata, output_type = 'probability')
s = input("Enter state or Union Territory: ")
giraffe_reviews = trialdata[trialdata['State/UT']== s]
giraffe_reviews = giraffe_reviews.sort('predicted_traits', ascending=False)
print('Traits of Dengue in '+ s +': ', giraffe_reviews[0]['traits_written'])
print('\n\n')
# Out:
# Enter state or Union Territory: Telangana
# Traits of Dengue in Telangana:  temperature range 26-29, high urbanization rate
